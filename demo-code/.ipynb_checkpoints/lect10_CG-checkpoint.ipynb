# %% [markdown]
# # <font color="green">Conjugate Gradient Method</font>
#
# ### We'll start off by importing what we need

# %%
import os
import math

import numpy as np
import numpy.linalg as npla

import scipy
import scipy.sparse.linalg as spla
from scipy import sparse
from scipy import linalg

import matplotlib
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import axes3d

# %%
def Jsolve(A, b, tol = 1e-8, max_iters = 1000, callback = None):
    """Solve a linear system Ax = b for x by the Jacobi iterative method.
    Parameters: 
      A: the matrix. Required to be a sparse matrix.
      b: the right-hand side vector.
      tol = 1e-8: the relative residual at which to stop iterating.
      max_iters = 1000: the maximum number of iterations to do. 
      callback = None: a user function to call at every iteration. 
        The callback function has arguments 'x', 'iteration', and 'residual'
    Outputs (in order):
      x: the computed solution
      rel_res: list of relative residual norms at each iteration.
        The number of iterations actually done is len(rel_res) - 1
    """
    # Check the input
    m, n = A.shape
    assert m == n, "matrix must be square"
    bn, = b.shape
    assert bn == n, "rhs vector must be same size as matrix"

    # Split A into diagonal D plus off-diagonal C
    d = A.diagonal()         # diagonal elements of A as a vector
    C = A.astype(np.float64).copy()    # copy of A ...
    
    C.setdiag(np.zeros(n))   # ... without the diagonal
    # could've also done: 
    # D from d
    # C = A - D
    
    # Initial guess: x = 0
    x = np.zeros(n)

    # Vector of relative residuals
    # Relative residual is norm(residual)/norm(b)
    # Intitial residual is b - Ax for x=0, or b
    rel_res = [1.0]
        
    # Call user function if specified
    if callback is not None:
        callback(x = x, iteration = 0, residual = 1)

    # Iterate
    for k in range(1, max_iters+1):
        # New x
        x = (b - C @ x) / d

        # Record relative residual
        this_rel_res = npla.norm(b - A @ x) / npla.norm(b)
        rel_res.append(this_rel_res)
                
        # Call user function if specified
        if callback is not None:
            callback(x = x, iteration = k, residual = this_rel_res)
                        
        # Stop if within tolerance    
        if this_rel_res <= tol:
            break
            
    return (x, rel_res)

# %%
def CGsolve(A, b, tol = 1e-8, max_iters = 1000, callback = None):
    """Solve a linear system Ax = b for x by the conjugate gradient iterative method.
    Parameters: 
      A: the matrix. Required to be a sparse matrix.
      b: the right-hand side vector.
      tol = 1e-8: the relative residual at which to stop iterating.
      max_iters = 1000: the maximum number of iterations to do. 
      callback = None: a user function to call at every iteration, with one argument x
    Outputs (in order):
      x: the computed solution
      rel_res: list of relative residual norms at each iteration.
        The number of iterations actually done is len(rel_res) - 1
    """
    # Check the input
    m, n = A.shape
    assert m == n, "matrix must be square"
    bn, = b.shape
    assert bn == n, "rhs vector must be same size as matrix"

    # Initial guess: x = 0
    x = np.zeros(n)
    
    # Initial residual: r = b - A@0 = b
    r = b
 
    # Initial step is in direction of residual.
    d = r

    # Squared norm of residual
    rtr = r.T @ r
    
    # Vector of relative residuals
    # Relative residual is norm(residual)/norm(b)
    # Intitial residual is b - Ax for x=0, or b
    rel_res = [1.0]
     
    # Call user function if specified
    if callback is not None:
        callback(x = x, iteration = 0, residual = 1)

    # Iterate
    for k in range(1, max_iters+1):
        Ad = A @ d
        alpha = rtr / (d.T @ Ad)  # Length of step
        x = x + alpha * d         # Update x to new x
        r = r - alpha * Ad        # Update r to new residual
        rtrold = rtr 
        rtr = r.T @ r
        beta = rtr / rtrold    
        d = r + beta * d          # Update d to new step direction
                   
        # Record relative residual
        this_rel_res = npla.norm(b - A @ x) / npla.norm(b)
        rel_res.append(this_rel_res)
                
        # Call user function if specified
        if callback is not None:
            callback(x = x, iteration = k, residual = this_rel_res)
                        
        # Stop if within tolerance    
        if this_rel_res <= tol:
            break
            
    return (x, rel_res)

# %% [markdown]
# # Re: Jacobi's Method

# %%
A = np.array([[4, -1, -1], [-2, 6, 1], [-1, 1, 7]])

# Alternative: NOT A DIAGONALLY DOMINANT MATRIX:
# A = np.array([[4, -10, -1], [-2, 6, 10], [-1, 12, 7]])

b = np.array([3, 9, -6])
print("A:\n", A)
print("\nb:\n", b)

x = npla.solve(A, b)
print("\nIdeal x (so we can compare against it):\n", x)
# Out:
# A:
#  [[ 4 -1 -1]
#  [-2  6  1]
#  [-1  1  7]]
#
# b:
#  [ 3  9 -6]
#
# Ideal x (so we can compare against it):
#  [ 1.  2. -1.]

# %%
#Run it using Jacobi
# IMPORTANT NOTE: Jsolve() requires A to be a sparse matrix
A = sparse.csr_matrix(A)

# Remember: JSolve() returns the x vector 
# AND a vector of all the iterated residual norms (a nice way to keep track)
#
# NOTE: The function Jsolve() has a default setting for "tolerance" (i.e. accuracy) at 1e-8,
# you can change that with option tol=...
#
x, res = Jsolve(A,b)
print("x and iterated residuals: \n", x, '\n\n', res)

# To see the last residual:
print(f"\n\nLast residual: {res[-1]:.3e}")  # Note the use of Python f-string for fix format of output

# To see how many iterations:
print("Number of iterations is:", len(res) - 1)
# Out:
# x and iterated residuals:
#  [ 1.00000001  1.99999999 -1.        ]
#
#  [1.0, 0.22768482384372116, 0.0503319479919278, 0.016047404414215965, 0.0035829971654077523, 0.001601864415303465, 0.00040285328778971063, 0.00021399546675719867, 6.959176731826758e-05, 3.4601335035126733e-05, 1.3174531968220623e-05, 6.075146130834141e-06, 2.479639411240011e-06, 1.0993499332232332e-06, 4.6202066343380954e-07, 2.0119957277470704e-07, 8.561022957943247e-08, 3.698871997266093e-08, 1.5822059686393463e-08, 6.8127044622987766e-09]
#
#
# Last residual: 6.813e-09
# Number of iterations is: 19

# %% [markdown]
# # Note: CG is not on Quiz 2...

# %% [markdown]
# # CG Method on a NON-SPD matrix

# %%
A = np.array([[4, -1, -1], [-2, 6, 1], [-1, 1, 7]])
print(A, '\n')

# But first...
# Is Matrix A an SPD (Symmetric Positive Definite) type?
if np.all(A.T == A) and np.all(npla.eig(A)[0] > 0):
    print("A is SPD matrix")
else:
    print("CAUTION: A is not SPD matrix")
# Out:
# [[ 4 -1 -1]
#  [-2  6  1]
#  [-1  1  7]]
#
# CAUTION: A is not SPD matrix

# %%
# Ok... let's A:\n", A)
b = np.array([3, 9, -6])
print("\nb:\n", b)

x = npla.solve(A, b)
#see the solution for Ax = b, given:

print("\nx:\n", x)
# Out:
# b:
#  [ 3  9 -6]
#
# x:
#  [ 1.  2. -1.]

# %%
A = sparse.csr_matrix(A)

x_cg, res = CGsolve(A, b)
print(x_cg, '\n')
print(res, '\n')
print("Number of iterations =", len(res) - 1)
# Out:
# [ 1.00000016  2.00000016 -1.00000002]
#
# [1.0, 0.16203391141302825, 0.05625588138469189, 0.012641623979466764, 0.0003656450913279317, 0.00013210332720738486, 3.715438255128129e-05, 8.641914496087437e-06, 4.850238673734118e-06, 1.6573719532673041e-06, 8.755263902110908e-07, 6.815346033700864e-07, 3.672576846090232e-07, 2.2434054342086348e-07, 1.9600973210155486e-07, 1.6325912155289314e-07, 1.0684131847481588e-07, 7.532260795256557e-08, 6.946802941604134e-08, 6.847435465759269e-08, 5.607866794946626e-08, 4.1224305255403794e-08, 3.334804199043325e-08, 3.226877567835983e-08, 3.388828411780135e-08, 3.298480554034237e-08, 2.839124020155891e-08, 2.326385749598556e-08, 2.0041355952047018e-08, 1.9207644604497005e-08, 2.016114692666912e-08, 2.1590034284925923e-08, 2.196243036672838e-08, 2.067297404550558e-08, 1.8408352206295514e-08, 1.6215221389858638e-08, 1.4746879307838154e-08, 1.420996013325008e-08, 1.4528226646709315e-08, 1.5428976195662676e-08, 1.647370155800271e-08, 1.7163736260060667e-08, 1.7160023788068446e-08, 1.6452619986397657e-08, 1.5309360155216472e-08, 1.4079644943348344e-08, 1.3041211189904033e-08, 1.2355245677390614e-08, 1.208437261583862e-08, 1.22205011993207e-08, 1.2700034034762416e-08, 1.3407502055433204e-08, 1.4180879378741916e-08, 1.483444621423209e-08, 1.520445068694754e-08, 1.5200682886113776e-08, 1.4832994153804581e-08, 1.419599938392673e-08, 1.3425633445299447e-08, 1.26556519360424e-08, 1.1991844792168713e-08, 1.1504754141471617e-08, 1.1233074874527851e-08, 1.1190009832123729e-08, 1.136817701283699e-08, 1.1741753584641939e-08, 1.226661344560834e-08, 1.2880561459028747e-08, 1.3506420027388413e-08, 1.4060246047408739e-08, 1.446476566201357e-08, 1.4664730207838672e-08, 1.4638424247417433e-08, 1.4400407892674016e-08, 1.3994725249438687e-08, 1.3482245744597388e-08, 1.2927489678754406e-08, 1.2388832161289698e-08, 1.1913318987711295e-08, 1.1535303658486796e-08, 1.127735787513174e-08, 1.1152043142105293e-08, 1.1163609272439207e-08, 1.1309163227151103e-08, 1.157920318947457e-08, 1.1957656762915794e-08, 1.24217397249651e-08, 1.2942069160778043e-08, 1.3483515937298452e-08, 1.4007201187014337e-08, 1.447375687433269e-08, 1.4847544116245806e-08, 1.5101036152162066e-08, 1.5218318519569348e-08, 1.5196780453560378e-08, 1.504660167189335e-08, 1.4788304635723295e-08, 1.4449161648278879e-08, 1.4059391986751359e-08, 1.3648898592190605e-08, 1.3244943280871997e-08, 1.2870814157679648e-08, 1.2545319897982257e-08, 1.22828518776762e-08, 1.209376053837369e-08, 1.1984843636237352e-08, 1.1959811259917061e-08, 1.2019649885003737e-08, 1.2162852631687343e-08, 1.2385519673658136e-08, 1.2681355521197716e-08, 1.3041610480730925e-08, 1.3455032118903829e-08, 1.3907902361902195e-08, 1.4384240727902412e-08, 1.4866239948986772e-08, 1.5334979362772093e-08, 1.5771404599874586e-08, 1.615750921770039e-08, 1.6477591103619366e-08, 1.6719412277868574e-08, 1.6875093175483873e-08, 1.694159773125977e-08, 1.692075160939852e-08, 1.6818802902238882e-08, 1.6645633967881915e-08, 1.641375700994249e-08, 1.613725036925505e-08, 1.583076639643052e-08, 1.5508700041420825e-08, 1.5184558928763588e-08, 1.4870546390665434e-08, 1.4577327328464268e-08, 1.4313944317278495e-08, 1.4087840473208244e-08, 1.3904947871645472e-08, 1.3769811142518307e-08, 1.3685719114198667e-08, 1.3654827359559049e-08, 1.3678260589412026e-08, 1.3756188717324547e-08, 1.3887875617809262e-08, 1.4071701575646168e-08, 1.4305164306809408e-08, 1.4584866979848405e-08, 1.4906499133759765e-08, 1.5264823261964432e-08, 1.5653681193279783e-08, 1.6066025568651312e-08, 1.6493996169587174e-08, 1.6929046965235598e-08, 1.7362128117716815e-08, 1.778392652559619e-08, 1.8185158141883076e-08, 1.8556895171292354e-08, 1.8890911294087568e-08, 1.9180019412247756e-08, 1.9418370685922133e-08, 1.9601693654783402e-08, 1.9727449887723248e-08, 1.979489454796014e-08, 1.9805040534771724e-08, 1.9760532096674938e-08, 1.9665443871181225e-08, 1.9525027409942178e-08, 1.934542847306187e-08, 1.913339645156826e-08, 1.889600840960656e-08, 1.864042001214863e-08, 1.8373654528363084e-08,  ...
#
# Number of iterations = 1000

# %% [markdown]
# ## Let's put in an SPD matrix for A this time!
# #### Will show you how FAST the CG Method is...!

# %%
# Using a SPD Matrix for A
A = np.array([[2,1],[1,3]])

# IS A SPD?
if (np.all(npla.eig(A)[0] > 0) and (np.all(A == A.T))):
    print("A is SPD matrix")
else:
    print("CAUTION: A is not SPD matrix")

b = np.array([1,1])
x = npla.solve(A, b)
print("\nx:\n", x)
# Out:
# A is SPD matrix
#
# x:
#  [0.4 0.2]

# %%
# Run CG on this using our CGsolve():
#  Remember: this function needs the input matrix to be in scipy.sparse form
A = sparse.csr_matrix(A)

x_cg, res = CGsolve(A, b)
print(x_cg, '\n')
print(res, '\n')
print("Number of iterations =", len(res) - 1)
# Out:
# [0.4 0.2]
#
# [1.0, 0.14285714285714285, 0.0]
#
# Number of iterations = 2

# %% [markdown]
# #### Let's compare w/ Jacobi's... same inputs...

# %%
x_j, resj = Jsolve(A, b)
print(x_j, '\n')
print(resj, '\n')
print("Number of iterations =", len(resj) - 1)
# Out:
# [0.4 0.2]
#
# [1.0, 0.42491829279939863, 0.1666666666666666, 0.07081971546656642, 0.027777777777777842, 0.011803285911094396, 0.00462962962962965, 0.0019672143185157326, 0.0007716049382716638, 0.00032786905308605704, 0.0001286008230452218, 5.464484218097322e-05, 2.1433470507536964e-05, 9.10747369692322e-06, 3.5722450845709903e-06, 1.5179122827915057e-06, 5.953741807340762e-07, 2.529853804071889e-07, 9.92290301038423e-08, 4.216423016221564e-08, 1.6538171720981154e-08, 7.027371664671586e-09]
#
# Number of iterations = 21

# %% [markdown]
# ### Using another SPD Matrix for A
# Try to get it to be diagonally dominant too

# %%
# Using another SPD Matrix for A (4x4)
A = np.array([[14, -1, 1, 2], [-1, 6, 1, 2], [1, 1, 7, 2], [2, 2, 2, 8]])


# IS MATRIX A SPD?
if (np.all(npla.eig(A)[0] > 0) and (np.all(A == A.T))):
    print("A is SPD matrix")
else:
    print("Caution: A is not SPD matrix")

    
# IS MATRIX A DIAG. DOM.?
Apos = np.abs(A)
flag = True
n,n = A.shape
for i in range(n):
    if Apos[i,i] <= np.sum(Apos[i, :] - Apos[i,i]):
        print("Caution: A is NOT Diagonally Dominant matrix")
        flag = False
        break
if flag:
    print("A is Diagonally Dominant matrix")
    
b = 10*np.random.rand(n)
x = npla.solve(A, b)
print("\nx:\n", x)
# Out:
# A is SPD matrix
# A is Diagonally Dominant matrix
#
# x:
#  [0.66287572 0.46229781 0.01424895 0.04263827]

# %%
# Run it on CG (should work well!)
A = sparse.csr_matrix(A)

x_cg, res = CGsolve(A, b)
print(x_cg, '\n')
print(res, '\n')
print("Number of iterations =", len(res) - 1)
# Out:
# [0.66287572 0.46229781 0.01424895 0.04263827]
#
# [1.0, 0.1698045255597214, 0.028721961060463257, 0.007899951362437646, 5.621458979633301e-16]
#
# Number of iterations = 4

# %%
# Let's compare with Jacobi (will it even work???)
x_j, res = Jsolve(A, b)
print(x_j, '\n')
print(res, '\n')
print("Number of iterations =", len(res) - 1)
# Out:
# [0.66287572 0.46229781 0.01424895 0.04263827]
#
# [1.0, 0.3060857256156864, 0.14999850416899438, 0.07277215342654957, 0.03653941925789479, 0.01828742355203146, 0.00923199594872742, 0.004654044804043803, 0.00235519245558369, 0.0011906042390951936, 0.000603094313172551, 0.0003052457771925685, 0.0001546724920287314, 7.832829973319655e-05, 3.9693577789840096e-05, 2.0106793888580648e-05, 1.0189327436196236e-05, 5.162116196639541e-06, 2.6159025228901167e-06, 1.3253659460523146e-06, 6.716142646865677e-07, 3.402922834890124e-07, 1.724361745880251e-07, 8.737174532987591e-08, 4.4273271106241615e-08, 2.243316244961033e-08, 1.1367296555973213e-08, 5.759833316522031e-09]
#
# Number of iterations = 27

# %% [markdown]
# # *Conclusion??*

# %% [markdown]
# # Let's do the temperature problem with Jacobi and CG!

# %%
def make_A(k):
    """Create the matrix for the temperature problem on a k-by-k grid.
    Parameters: 
      k: number of grid points in each dimension.
    Outputs:
      A: the sparse k**2-by-k**2 matrix representing the finite difference approximation to Poisson's equation.
    """
    # First make a list with one triple (row, column, value) for each nonzero element of A
    triples = []
    for i in range(k):
        for j in range(k):
            # what row of the matrix is grid point (i,j)?
            row = j + i*k
            # the diagonal element in this row
            triples.append((row, row, 4.0))
            # connect to left grid neighbor
            if j > 0:
                triples.append((row, row - 1, -1.0))
            # ... right neighbor
            if j < k - 1:
                triples.append((row, row + 1, -1.0))
            # ... neighbor above
            if i > 0:
                triples.append((row, row - k, -1.0))
            # ... neighbor below
            if i < k - 1:
                triples.append((row, row + k, -1.0))
    
    # Finally convert the list of triples to a scipy sparse matrix
    ndim = k*k
    rownum = [t[0] for t in triples]
    colnum = [t[1] for t in triples]
    values = [t[2] for t in triples]
    A = sparse.csr_matrix((values, (rownum, colnum)), shape = (ndim, ndim))
    
    return A

# %%
def make_b(k, top = 0, bottom = 0, left = 0, right = 0):
    """Create the right-hand side for the temperature problem on a k-by-k grid.
    Parameters: 
      k: number of grid points in each dimension.
      top: list of k values for top boundary (optional, defaults to 0)
      bottom: list of k values for bottom boundary (optional, defaults to 0)
      left: list of k values for top boundary (optional, defaults to 0)
      right: list of k values for top boundary (optional, defaults to 0)
    Outputs:
      b: the k**2 element vector (as a numpy array) for the rhs of the Poisson equation with given boundary conditions
    """
    # Start with a vector of zeros
    ndim = k*k
    b = np.zeros(shape = ndim)
    
    # Fill in the four boundaries as appropriate
    b[0        : k       ] += top
    b[ndim - k : ndim    ] += bottom
    b[0        : ndim : k] += left
    b[k-1      : ndim : k] += right
    
    return b

# %%
def radiator(k, width = .3, temperature = 100.):
    """Create one wall with a radiator
    Parameters: 
      k: number of grid points in each dimension; length of the wall.
      width: width of the radiator as a fraction of length of the wall (defaults to 0.2)
      temperature: temperature of the radiator (defaults to 100)
    Outputs:
      wall: the k element vector (as a numpy array) for the boundary conditions at the wall
    """
    rad_start = int(k * (0.5 - width/2))
    rad_end = int(k * (0.5 + width/2))
    wall = np.zeros(k)
    wall[rad_start : rad_end] = temperature
    
    return wall

# %% [markdown]
# ## Run it for a large $k$ value (so, even larger $k^2$ value)

# %%
k = 1000
rad_wall = radiator(k)
A = make_A(k)
b = make_b(k, right = rad_wall)

t = spla.spsolve(A,b)

print("t:", t)
print("size:", t.size)
# Out:
# t: [4.86570101e-05 9.73144525e-05 1.45972760e-04 ... 1.06778205e-03
#  7.11893262e-04 3.55958200e-04]
# size: 1000000

# %%
#Set it up for plotting and then plot 3D projection
T = t.reshape(k,k)
X, Y = np.meshgrid(range(k), range(k))

#%matplotlib inline
# %matplotlib notebook

#get_ipython().run_line_magic('matplotlib', 'tk')
#%matplotlib tk
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.plot_surface(X, Y, T, cmap=cm.hot)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### First with Jacobi

# %%
# Try this for value of max_iters from 10 to 10000, and visualize them with the cell above

t, resvec = Jsolve(A, b, max_iters = 100)
# print(resvec[-1])

# Re-plot
T = t.reshape(k,k)
X, Y = np.meshgrid(range(k), range(k))
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.plot_surface(X, Y, T, cmap=cm.hot)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Next with CG

# %%
# Try this for value of max_iters from 10 to 10000, and visualize them with the cell above

t, resvec = CGsolve(A, b, max_iters = 1000)
# print(resvec[-1])

# Re-plot
T = t.reshape(k,k)
X, Y = np.meshgrid(range(k), range(k))
#%matplotlib tk
get_ipython().run_line_magic('matplotlib', 'tk')
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.plot_surface(X, Y, T, cmap=cm.hot)
# Out:
# Warning: Cannot change to a different GUI toolkit: tk. Using notebook instead.
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Comparing Jacobi vs CG

# %%
# Plot relative residual (y axis) versus iteration number (x axis) for both Jacobi and CG

#%matplotlib inline
plt.figure()

# Plot the Jacobi residual error values over each iteration
(xJ,resvecJ) = Jsolve(A, b, tol = 1e-10, max_iters = 1000)
plt.semilogy(resvecJ, label = 'Jacobi')

# Plot the CG residual error values over each iteration
(xCG,resvecCG) = CGsolve(A, b, tol = 1e-10, max_iters = 1000)
plt.semilogy(resvecCG, label = 'CG')

# Give the plot a legend, x- and y-axis labels, and a title
plt.legend()
plt.xlabel('iterations')
plt.ylabel('relative residual')
plt.title('Iterative methods for temperature problem with n = %d' % A.shape[0])


# Print out some relevant information from each method:
#    How many total iterations?
#    What was the last residual error value?
#    How "true" to the ideal was the final solution (i.e., relative residual error compared to ideal)?

print('\nJacobi iters:', len(resvecJ)-1)
print('last rel res:', resvecJ[-1])
print('computed rel res:', npla.norm(A@xJ - b) / npla.norm(b))

print('\nCG iters:', len(resvecCG)-1)
print('last rel res:', resvecCG[-1])
print('computed rel res:', npla.norm(A@xCG - b) / npla.norm(b))
# Out:
# <img src="data:image/png;base64,..." width="640">
# Jacobi iters: 1000
# last rel res: 0.004804043061760523
# computed rel res: 0.004804043061760523
#
# CG iters: 1000
# last rel res: 0.0006339643581608139
# computed rel res: 0.0006339643581608139
